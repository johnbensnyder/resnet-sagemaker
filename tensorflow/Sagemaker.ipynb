# %%
import sys
import importlib
import os
import boto3
import json
from sagemaker import get_execution_role
from sagemaker.tensorflow import TensorFlow
from datetime import datetime
import os
import pprint
import subprocess

# %%
# Login to ECR and select training image
region = "us-west-2"
set_region = f"aws configure set region {region} --profile default"
_ = subprocess.check_output(set_region, shell=True)

# %%
role = get_execution_role()

# %%
instance_count = 4
instance_type = "ml.p4d.24xlarge"
if instance_type=='local_gpu':
    local_gpu_count = int(subprocess.check_output("nvidia-smi --query-gpu=name --format=csv,noheader | wc -l", shell=True).decode().strip())
processes_per_host = 8 if instance_type in ["ml.p3dn.24xlarge", "ml.p4d.24xlarge", "ml.p3.16xlarge"] \
                     else 4 if instance_type in ["ml.p3.8xlarge", "ml.g4dn.12xlarge"] \
                     else local_gpu_count if instance_type=='local_gpu' else 1

# %%
user_id = "jbsnyder"
date_str = datetime.now().strftime("%d-%m-%Y")
time_str = datetime.now().strftime("%d-%m-%Y-%H-%M-%S")
job_name = '{}-{}'.format(user_id, time_str)

# %%
s3_bucket = "jbsnyder-sagemaker-pdx" if region=="us-west-2" else "jbsnyder-sagemaker-iad"
s3_path = os.path.join('s3://{}/'.format(s3_bucket))

s3_data_dir = "s3://{}/data/".format(s3_bucket)
imagenet_tfrecord = "imagenet/tfrecord"

channels = {
    'train': os.path.join(s3_data_dir, imagenet_tfrecord, 'train'),
    'validation': os.path.join(s3_data_dir, imagenet_tfrecord, 'validation')
}

output_path = os.path.join(s3_path, "sagemaker-output", date_str, job_name)

code_location = os.path.join(s3_path, "sagemaker-code", date_str, job_name)

# %%
pipe_mode = False

batch_size = instance_count * 1024

lr = batch_size / 256 * 0.01

hyperparameters = {"train_data_dir": channels['train'], # "/opt/ml/input/data/train",
                   "validation_data_dir": channels['validation'], # "/opt/ml/input/data/validation",
                   "batch_size": batch_size,
                   "num_epochs": 120,
                   "model_dir": "/opt/ml/checkpoints",
                   "learning_rate": lr,
                   "momentum": 0.9,
                   "label_smoothing": 0.1,
                   "mixup_alpha": 0.2,
                   "l2_weight_decay": 2.5e-5,
                   "fp16": "True",
                   "xla": "True",
                   "tf32": "True",
                   "model": "resnet152v1_d",
                   "pipe_mode": str(pipe_mode)}

# %%
source_dir = "."
entry_point = "train.py"

# %%
distribution_type='smd' if instance_count>1 else 'hvd'

# distribution_type = 'hvd'

if distribution_type=="smd":
    distribution = { "smdistributed": { "dataparallel": { "enabled": True } } } 
elif distribution_type=="hvd":
    custom_mpi_options = mpi_options = [
         '-x TF_CUDNN_USE_AUTOTUNE=0',
         '-x FI_EFA_USE_DEVICE_RDMA=1',
    ]
    distribution = {
    "mpi": {
        "enabled": True,
        "processes_per_host": processes_per_host,
        "custom_mpi_options": " ".join(custom_mpi_options)
        }
    }

# %%
estimator = TensorFlow(
                entry_point=entry_point, 
                source_dir=source_dir, 
                image_uri='427566855058.dkr.ecr.us-west-2.amazonaws.com/jbsnyder:tf-2.5-cudnn-8.2',
                role=role,
                instance_count=instance_count,
                instance_type=instance_type,
                distribution=distribution,
                output_path=None if "local" in instance_type else output_path,
                checkpoint_s3_uri=None if "local" in instance_type else output_path,
paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-07-13 08:48:13,822 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-07-13 08:48:13,823 sagemaker-training-toolkit INFO     Can connect to host algo-4 at port 22
# 2021-07-13 08:48:13,823 sagemaker-training-toolkit INFO     Connection closed
# 2021-07-13 08:48:13,823 sagemaker-training-toolkit INFO     Worker algo-4 available for communication
# 2021-07-13 08:48:13,823 sagemaker-training-toolkit INFO     Network interface name: eth0
# 2021-07-13 08:48:13,823 sagemaker-training-toolkit INFO     Host: ['algo-1', 'algo-2', 'algo-3', 'algo-4']
# 2021-07-13 08:48:13,824 sagemaker-training-toolkit INFO     instance type: ml.p4d.24xlarge
# 2021-07-13 08:48:13,913 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_distributed_dataparallel_enabled": true,
#         "sagemaker_instance_type": "ml.p4d.24xlarge",
#         "sagemaker_distributed_dataparallel_custom_mpi_options": ""
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4"
#     ],
#     "hyperparameters": {
#         "batch_size": 4096,
#         "tf32": "True",
#         "mixup_alpha": 0.2,
#         "xla": "True",
#         "label_smoothing": 0.1,
#         "momentum": 0.9,
#         "validation_data_dir": "s3://jbsnyder-sagemaker-pdx/data/imagenet/tfrecord/validation",
#         "pipe_mode": "False",
#         "model": "resnet152v1_d",
#         "model_dir": "s3://jbsnyder-sagemaker-pdx/sagemaker-output/13-07-2021/jbsnyder-13-07-2021-08-37-34",
#         "learning_rate": 0.16,
#         "l2_weight_decay": 2.5e-05,
#         "num_epochs": 120,
#         "fp16": "True",
#         "train_data_dir": "s3://jbsnyder-sagemaker-pdx/data/imagenet/tfrecord/train"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "jbsnyder-13-07-2021-08-37-34",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://jbsnyder-sagemaker-pdx/sagemaker-code/13-07-2021/jbsnyder-13-07-2021-08-37-34/jbsnyder-13-07-2021-08-37-34/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 96,
#     "num_gpus": 8,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":4096,"fp16":"True","l2_weight_decay":2.5e-05,"label_smoothing":0.1,"learning_rate":0.16,"mixup_alpha":0.2,"model":"resnet152v1_d","model_dir":"s3://jbsnyder-sagemaker-pdx/sagemaker-output/13-07-2021/jbsnyder-13-07-2021-08-37-34","momentum":0.9,"num_epochs":120,"pipe_mode":"False","tf32":"True","train_data_dir":"s3://jbsnyder-sagemaker-pdx/data/imagenet/tfrecord/train","validation_data_dir":"s3://jbsnyder-sagemaker-pdx/data/imagenet/tfrecord/validation","xla":"True"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={"sagemaker_distributed_dataparallel_custom_mpi_options":"","sagemaker_distributed_dataparallel_enabled":true,"sagemaker_instance_type":"ml.p4d.24xlarge"}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2","algo-3","algo-4"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=96
# SM_NUM_GPUS=8
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://jbsnyder-sagemaker-pdx/sagemaker-code/13-07-2021/jbsnyder-13-07-2021-08-37-34/jbsnyder-13-07-2021-08-37-34/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_distributed_dataparallel_custom_mpi_options":"","sagemaker_distributed_dataparallel_enabled":true,"sagemaker_instance_type":"ml.p4d.24xlarge"},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4"],"hyperparameters":{"batch_size":4096,"fp16":"True","l2_weight_decay":2.5e-05,"label_smoothing":0.1,"learning_rate":0.16,"mixup_alpha":0.2,"model":"resnet152v1_d","model_dir":"s3://jbsnyder-sagemaker-pdx/sagemaker-output/13-07-2021/jbsnyder-13-07-2021-08-37-34","momentum":0.9,"num_epochs":120,"pipe_mode":"False","tf32":"True","train_data_dir":"s3://jbsnyder-sagemaker-pdx/data/imagenet/tfrecord/train","validation_data_dir":"s3://jbsnyder-sagemaker-pdx/data/imagenet/tfrecord/validation","xla":"True"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"jbsnyder-13-07-2021-08-37-34","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://jbsnyder-sagemaker-pdx/sagemaker-code/13-07-2021/jbsnyder-13-07-2021-08-37-34/jbsnyder-13-07-2021-08-37-34/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":96,"num_gpus":8,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2","algo-3","algo-4"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch_size","4096","--fp16","True","--l2_weight_decay","2.5e-05","--label_smoothing","0.1","--learning_rate","0.16","--mixup_alpha","0.2","--model","resnet152v1_d","--model_dir","s3://jbsnyder-sagemaker-pdx/sagemaker-output/13-07-2021/jbsnyder-13-07-2021-08-37-34","--momentum","0.9","--num_epochs","120","--pipe_mode","False","--tf32","True","--train_data_dir","s3://jbsnyder-sagemaker-pdx/data/imagenet/tfrecord/train","--validation_data_dir","s3://jbsnyder-sagemaker-pdx/data/imagenet/tfrecord/validation","--xla","True"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH_SIZE=4096
# SM_HP_TF32=True
# SM_HP_MIXUP_ALPHA=0.2
# SM_HP_XLA=True
# SM_HP_LABEL_SMOOTHING=0.1
# SM_HP_MOMENTUM=0.9
# SM_HP_VALIDATION_DATA_DIR=s3://jbsnyder-sagemaker-pdx/data/imagenet/tfrecord
[6] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,20]<stdout>:algo-3:281:536 [4] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,21]<stdout>:algo-3:287:535 [5] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,16]<stdout>:algo-3:378:538 [0] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,17]<stdout>:algo-3:283:540 [1] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,18]<stdout>:algo-3:285:541 [2] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,19]<stdout>:algo-3:282:539 [3] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,13]<stdout>:algo-2:279:539 [5] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,14]<stdout>:algo-2:280:540 [6] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,12]<stdout>:algo-2:287:541 [4] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,8]<stdout>:algo-2:378:537 [0] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,9]<stdout>:algo-2:286:536 [1] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,15]<stdout>:algo-2:283:538 [7] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,11]<stdout>:algo-2:284:534 [3] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,10]<stdout>:algo-2:285:535 [2] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,30]<stdout>:algo-4:285:538 [6] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,31]<stdout>:algo-4:284:537 [7] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,28]<stdout>:algo-4:280:540 [4] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,29]<stdout>:algo-4:283:536 [5] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,24]<stdout>:algo-4:378:555 [0] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,25]<stdout>:algo-4:286:539 [1] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,27]<stdout>:algo-4:279:534 [3] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,26]<stdout>:algo-4:287:535 [2] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,4]<stdout>:algo-1:302:560 [4] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,4]<stdout>:algo-1:302:560 [4] NCCL INFO NET/OFI Selected Provider is efa
# [1,4]<stdout>:algo-1:302:560 [4] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,4]<stdout>:algo-1:302:560 [4] NCCL INFO Using network AWS Libfabric
# [1,3]<stdout>:algo-1:305:554 [3] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,3]<stdout>:algo-1:305:554 [3] NCCL INFO NET/OFI Selected Provider is efa
# [1,3]<stdout>:algo-1:305:554 [3] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,3]<stdout>:algo-1:305:554 [3] NCCL INFO Using network AWS Libfabric
# [1,1]<stdout>:algo-1:301:553 [1] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,1]<stdout>:algo-1:301:553 [1] NCCL INFO NET/OFI Selected Provider is efa
# [1,2]<stdout>:algo-1:300:555 [2] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,2]<stdout>:algo-1:300:555 [2] NCCL INFO NET/OFI Selected Provider is efa
# [1,1]<stdout>:algo-1:301:553 [1] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,2]<stdout>:algo-1:300:555 [2] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,1]<stdout>:algo-1:301:553 [1] NCCL INFO Using network AWS Libfabric
# [1,2]<stdout>:algo-1:300:555 [2] NCCL INFO Using network AWS Libfabric
# [1,5]<stdout>:algo-1:304:558 [5] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,5]<stdout>:algo-1:304:558 [5] NCCL INFO NET/OFI Selected Provider is efa
# [1,7]<stdout>:algo-1:306:557 [7] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,7]<stdout>:algo-1:306:557 [7] NCCL INFO NET/OFI Selected Provider is efa
# [1,6]<stdout>:algo-1:303:559 [6] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,6]<stdout>:algo-1:303:559 [6] NCCL INFO NET/OFI Selected Provider is efa
# [1,5]<stdout>:algo-1:304:558 [5] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,5]<stdout>:algo-1:304:558 [5] NCCL INFO Using network AWS Libfabric
# [1,7]<stdout>:algo-1:306:557 [7] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,7]<stdout>:algo-1:306:557 [7] NCCL INFO Using network AWS Libfabric
# [1,6]<stdout>:algo-1:303:559 [6] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,6]<stdout>:algo-1:303:559 [6] NCCL INFO Using network AWS Libfabric
# [1,28]<stdout>:algo-4:280:540 [4] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,28]<stdout>:algo-4:280:540 [4] NCCL INFO NET/OFI Selected Provider is efa
# [1,29]<stdout>:algo-4:283:536 [5] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,29]<stdout>:algo-4:283:536 [5] NCCL INFO NET/OFI Selected Provider is efa
# [1,29]<stdout>:algo-4:283:536 [5] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,29]<stdout>:algo-4:283:536 [5] NCCL INFO Using network AWS Libfabric
# [1,28]<stdout>:algo-4:280:540 [4] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,28]<stdout>:algo-4:280:540 [4] NCCL INFO Using network AWS Libfabric
# [1,27]<stdout>:algo-4:279:534 [3] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,27]<stdout>:algo-4:279:534 [3] NCCL INFO NET/OFI Selected Provider is efa
# [1,27]<stdout>:algo-4:279:534 [3] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,27]<stdout>:algo-4:279:534 [3] NCCL INFO Using network AWS Libfabric
# [1,26]<stdout>:algo-4:287:535 [2] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,26]<stdout>:algo-4:287:535 [2] NCCL INFO NET/OFI Selected Provider is efa
# [1,24]<stdout>:algo-4:378:555 [0] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,24]<stdout>:algo-4:378:555 [0] NCCL INFO NET/OFI Selected Provider is efa
# [1,25]<stdout>:algo-4:286:539 [1] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,25]<stdout>:algo-4:286:539 [1] NCCL INFO NET/OFI Selected Provider is efa
# [1,26]<stdout>:algo-4:287:535 [2] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,26]<stdout>:algo-4:287:535 [2] NCCL INFO Using network AWS Libfabric
# [1,24]<stdout>:algo-4:378:555 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,24]<stdout>:algo-4:378:555 [0] NCCL INFO Using network AWS Libfabric
# [1,25]<stdout>:algo-4:286:539 [1] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,25]<stdout>:algo-4:286:539 [1] NCCL INFO Using network AWS Libfabric
# [1,30]<stdout>:algo-4:285:538 [6] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,30]<stdout>:algo-4:285:538 [6] NCCL INFO NET/OFI Selected Provider is efa
# [1,30]<stdout>:algo-4:285:538 [6] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,31]<stdout>:algo-4:284:537 [7] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,31]<stdout>:algo-4:284:537 [7] NCCL INFO NET/OFI Selected Provider is efa
# [1,31]<stdout>:algo-4:284:537 [7] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,30]<stdout>:algo-4:285:538 [6] NCCL INFO Using network AWS Libfabric
# [1,31]<stdout>:algo-4:284:537 [7] NCCL INFO Using network AWS Libfabric
# [1,15]<stdout>:algo-2:283:538 [7] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,15]<stdout>:algo-2:283:538 [7] NCCL INFO NET/OFI Selected Provider is efa
# [1,15]<stdout>:algo-2:283:538 [7] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,15]<stdout>:algo-2:283:538 [7] NCCL INFO Using network AWS Libfabric
# [1,18]<stdout>:algo-3:285:541 [2] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,18]<stdout>:algo-3:285:541 [2] NCCL INFO NET/OFI Selected Provider is efa
# [1,18]<stdout>:algo-3:285:541 [2] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,18]<stdout>:algo-3:285:541 [2] NCCL INFO Using network AWS Libfabric
# [1,19]<stdout>:algo-3:282:539 [3] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,19]<stdout>:algo-3:282:539 [3] NCCL INFO NET/OFI Selected Provider is efa
# [1,19]<stdout>:algo-3:282:539 [3] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,19]<stdout>:algo-3:282:539 [3] NCCL INFO Using network AWS Libfabric
# [1,14]<stdout>:algo-2:280:540 [6] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,14]<stdout>:algo-2:280:540 [6] NCCL INFO NET/OFI Selected Provider is efa
# [1,14]<stdout>:algo-2:280:540 [6] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,14]<stdout>:algo-2:280:540 [6] NCCL INFO Using network AWS Libfabric
# [1,13]<stdout>:algo-2:279:539 [5] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,13]<stdout>:algo-2:279:539 [5] NCCL INFO NET/OFI Selected Provider is efa
# [1,12]<stdout>:algo-2:287:541 [4] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,12]<stdout>:algo-2:287:541 [4] NCCL INFO NET/OFI Selected Provider is efa
# [1,13]<stdout>:algo-2:279:539 [5] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,13]<stdout>:algo-2:279:539 [5] NCCL INFO Using network AWS Libfabric
# [1,20]<stdout>:algo-3:281:536 [4] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,20]<stdout>:algo-3:281:536 [4] NCCL INFO NET/OFI Selected Provider is efa
# [1,20]<stdout>:algo-3:281:536 [4] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,20]<stdout>:algo-3:281:536 [4] NCCL INFO Using network AWS Libfabric
# [1,23]<stdout>:algo-3:284:534 [7] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,23]<stdout>:algo-3:284:534 [7] NCCL INFO NET/OFI Selected Provider is efa
# [1,23]<stdout>:algo-3:284:534 [7] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,23]<stdout>:algo-3:284:534 [7] NCCL INFO Using network AWS Libfabric
# [1,12]<stdout>:algo-2:287:541 [4] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,12]<stdout>:algo-2:287:541 [4] NCCL INFO Using network AWS Libfabric
# [1,21]<stdout>:algo-3:287:535 [5] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,21]<stdout>:algo-3:287:535 [5] NCCL INFO NET/OFI Selected Provider is efa
# [1,21]<stdout>:algo-3:287:535 [5] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,21]<stdout>:algo-3:287:535 [5] NCCL INFO Using network AWS Libfabric
# [1,16]<stdout>:algo-3:378:538 [0] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,16]<stdout>:algo-3:378:538 [0] NCCL INFO NET/OFI Selected Provider is efa
# [1,16]<stdout>:algo-3:378:538 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,16]<stdout>:algo-3:378:538 [0] NCCL INFO Using network AWS Libfabric
# [1,17]<stdout>:algo-3:283:540 [1] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,17]<stdout>:algo-3:283:540 [1] NCCL INFO NET/OFI Selected Provider is efa
# [1,17]<stdout>:algo-3:283:540 [1] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,17]<stdout>:algo-3:283:540 [1] NCCL INFO Using network AWS Libfabric
# [1,22]<stdout>:algo-3:286:537 [6] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,22]<stdout>:algo-3:286:537 [6] NCCL INFO NET/OFI Selected Provider is efa
# [1,22]<stdout>:algo-3:286:537 [6] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,22]<stdout>:algo-3:286:537 [6] NCCL INFO Using network AWS Libfabric
# [1,8]<stdout>:algo-2:378:537 [0] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,8]<stdout>:algo-2:378:537 [0] NCCL INFO NET/OFI Selected Provider is efa
# [1,8]<stdout>:algo-2:378:537 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,9]<stdout>:algo-2:286:536 [1] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,9]<stdout>:algo-2:286:536 [1] NCCL INFO NET/OFI Selected Provider is efa
# [1,10]<stdout>:algo-2:285:535 [2] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,10]<stdout>:algo-2:285:535 [2] NCCL INFO NET/OFI Selected Provider is efa
# [1,10]<stdout>:algo-2:285:535 [2] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,10]<stdout>:algo-2:285:535 [2] NCCL INFO Using network AWS Libfabric
# [1,11]<stdout>:algo-2:284:534 [3] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,11]<stdout>:algo-2:284:534 [3] NCCL INFO NET/OFI Selected Provider is efa
# [1,11]<stdout>:algo-2:284:534 [3] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,11]<stdout>:algo-2:284:534 [3] NCCL INFO Using network AWS Libfabric
# [1,8]<stdout>:algo-2:378:537 [0] NCCL INFO Using network AWS Libfabric
# [1,9]<stdout>:algo-2:286:536 [1] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,9]<stdout>:algo-2:286:536 [1] NCCL INFO Using network AWS Libfabric
# [1,7]<stdout>:algo-1:306:557 [7] NCCL INFO NET/OFI [7] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10
# [1,7]<stdout>:algo-1:306:557 [7] NCCL INFO NET/OFI [7] getCudaPath dev 1 busId 0000:10:1d.0 path /sys/devices/pci0000:10
# [1,4]<stdout>:algo-1:302:560 [4] NCCL INFO NET/OFI [4] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10
# [1,5]<stdout>:algo-1:304:558 [5] NCCL INFO NET/OFI [5] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10
# [1,6]<stdout>:algo-1:303:559 [6] NCCL INFO NET/OFI [6] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10
# [1,20]<stdout>:algo-3:281:536 [4] NCCL INFO NET/OFI [4] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10
# [1,23]<stdout>:algo-3:284:534 [7] NCCL INFO NET/OFI [7] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10
# [1,23]<stdout>:algo-3:284:534 [7] NCCL INFO NET/OFI [7] getCudaPath dev 1 busId 0000:10:1d.0 path /sys/devices/pci0000:10
# [1,14]<stdout>:algo-2:280:540 [6] NCCL INFO NET/OFI [6] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10
# [1,3]<stdout>:algo-1:305:554 [3] NCCL INFO NET/OFI [3] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10
# [1,15]<stdout>:algo-2:283:538 [7] NCCL INFO NET/OFI [7] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10
# [1,25]<stdout>:algo-4:286:539 [1] NCCL INFO NET/OFI [1] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10/
# [1,13]<stdout>:algo-2:279:539 [5] NCCL INFO NET/OFI [5] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10
# [1,12]<stdout>:algo-2:287:541 [4] NCCL INFO NET/OFI [4] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10
# [1,11]<stdout>:algo-2:284:534 [3] NCCL INFO NET/OFI [3] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10
# [1,24]<stdout>:algo-4:378:555 [0] NCCL INFO NET/OFI [0] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10/
# [1,8]<stdout>:algo-2:378:537 [0] NCCL INFO NET/OFI [0] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10/
# [1,5]<stdout>:algo-1:304:558 [5] NCCL INFO NET/OFI [5] getCudaPath dev 1 busId 0000:10:1d.0 path /sys/devices/pci0000:10
# [1,6]<stdout>:algo-1:303:559 [6] NCCL INFO NET/OFI [6] getCudaPath dev 1 busId 0000:10:1d.0 path /sys/devices/pci0000:10
# [1,26]<stdout>:algo-4:287:535 [2] NCCL INFO NET/OFI [2] getCudaPath dev 0 busId 0000:10:1c.0 path /sys/devices/pci0000:10
# ...
# [1,15]<stdout>:algo-2:283:538 [7] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,15]<stdout>:algo-2:283:538 [7] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,15]<stdout>:algo-2:283:538 [7] NCCL INFO comm 0x7fe5d4398770 rank 15 nranks 32 cudaDev 7 busId a01d0 - Init COMPLETE
# [1,7]<stdout>:algo-1:306:557 [7] NCCL INFO Connected all trees
# [1,7]<stdout>:algo-1:306:557 [7] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,7]<stdout>:algo-1:306:557 [7] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,7]<stdout>:algo-1:306:557 [7] NCCL INFO comm 0x7f4dac383b50 rank 7 nranks 32 cudaDev 7 busId a01d0 - Init COMPLETE
# [1,2]<stdout>:algo-1:300:555 [2] NCCL INFO Connected all trees
# [1,2]<stdout>:algo-1:300:555 [2] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,2]<stdout>:algo-1:300:555 [2] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,2]<stdout>:algo-1:300:555 [2] NCCL INFO comm 0x7f7e80391600 rank 2 nranks 32 cudaDev 2 busId 201c0 - Init COMPLETE
# [1,3]<stdout>:algo-1:305:554 [3] NCCL INFO Connected all trees
# [1,3]<stdout>:algo-1:305:554 [3] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,3]<stdout>:algo-1:305:554 [3] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,3]<stdout>:algo-1:305:554 [3] NCCL INFO comm 0x7fa64c391010 rank 3 nranks 32 cudaDev 3 busId 201d0 - Init COMPLETE
# [1,0]<stdout>:algo-1:397:556 [0] NCCL INFO Connected all trees
# [1,0]<stdout>:algo-1:397:556 [0] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,0]<stdout>:algo-1:397:556 [0] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,0]<stdout>:algo-1:397:556 [0] NCCL INFO comm 0x7f3758ac8ae0 rank 0 nranks 32 cudaDev 0 busId 101c0 - Init COMPLETE
# [1,1]<stdout>:algo-1:301:553 [1] NCCL INFO Connected all trees
# [1,1]<stdout>:algo-1:301:553 [1] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,1]<stdout>:algo-1:301:553 [1] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,1]<stdout>:algo-1:301:553 [1] NCCL INFO comm 0x7f4c3c390b10 rank 1 nranks 32 cudaDev 1 busId 101d0 - Init COMPLETE
# [1,18]<stdout>:algo-3:285:541 [2] NCCL INFO Connected all trees
# [1,18]<stdout>:algo-3:285:541 [2] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,18]<stdout>:algo-3:285:541 [2] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,18]<stdout>:algo-3:285:541 [2] NCCL INFO comm 0x7ff64c398950 rank 18 nranks 32 cudaDev 2 busId 201c0 - Init COMPLETE
# [1,9]<stdout>:algo-2:286:536 [1] NCCL INFO Channel 00 : 9[101d0] -> 8[101c0] via P2P/IPC/read
# [1,9]<stdout>:algo-2:286:536 [1] NCCL INFO Channel 02 : 9[101d0] -> 8[101c0] via P2P/IPC/read
# [1,11]<stdout>:algo-2:284:534 [3] NCCL INFO Channel 01 : 11[201d0] -> 10[201c0] via P2P/IPC/read
# [1,19]<stdout>:algo-3:282:539 [3] NCCL INFO Connected all trees
# [1,19]<stdout>:algo-3:282:539 [3] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,19]<stdout>:algo-3:282:539 [3] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,19]<stdout>:algo-3:282:539 [3] NCCL INFO comm 0x7f63e03987b0 rank 19 nranks 32 cudaDev 3 busId 201d0 - Init COMPLETE
# [1,16]<stdout>:algo-3:378:538 [0] NCCL INFO Connected all trees
# [1,16]<stdout>:algo-3:378:538 [0] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,16]<stdout>:algo-3:378:538 [0] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,16]<stdout>:algo-3:378:538 [0] NCCL INFO comm 0x7f75ac3a7e30 rank 16 nranks 32 cudaDev 0 busId 101c0 - Init COMPLETE
# [1,17]<stdout>:algo-3:283:540 [1] NCCL INFO Connected all trees
# [1,17]<stdout>:algo-3:283:540 [1] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,17]<stdout>:algo-3:283:540 [1] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,17]<stdout>:algo-3:283:540 [1] NCCL INFO comm 0x7f0ed4398910 rank 17 nranks 32 cudaDev 1 busId 101d0 - Init COMPLETE
# [1,9]<stdout>:algo-2:286:536 [1] NCCL INFO Connected all trees
# [1,9]<stdout>:algo-2:286:536 [1] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,9]<stdout>:algo-2:286:536 [1] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,9]<stdout>:algo-2:286:536 [1] NCCL INFO comm 0x7fa0543982f0 rank 9 nranks 32 cudaDev 1 busId 101d0 - Init COMPLETE
# [1,11]<stdout>:algo-2:284:534 [3] NCCL INFO Channel 03 : 11[201d0] -> 10[201c0] via P2P/IPC/read
# [1,8]<stdout>:algo-2:378:537 [0] NCCL INFO Connected all trees
# [1,8]<stdout>:algo-2:378:537 [0] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,8]<stdout>:algo-2:378:537 [0] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,8]<stdout>:algo-2:378:537 [0] NCCL INFO comm 0x7f17e4391a20 rank 8 nranks 32 cudaDev 0 busId 101c0 - Init COMPLETE
# [1,12]<stdout>:algo-2:287:541 [4] NCCL INFO Connected all trees
# [1,12]<stdout>:algo-2:287:541 [4] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,12]<stdout>:algo-2:287:541 [4] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,12]<stdout>:algo-2:287:541 [4] NCCL INFO comm 0x7fca9c399600 rank 12 nranks 32 cudaDev 4 busId 901c0 - Init COMPLETE
# [1,10]<stdout>:algo-2:285:535 [2] NCCL INFO Connected all trees
# [1,10]<stdout>:algo-2:285:535 [2] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,10]<stdout>:algo-2:285:535 [2] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,10]<stdout>:algo-2:285:535 [2] NCCL INFO comm 0x7fed30398930 rank 10 nranks 32 cudaDev 2 busId 201c0 - Init COMPLETE
# [1,11]<stdout>:algo-2:284:534 [3] NCCL INFO Connected all trees
# [1,11]<stdout>:algo-2:284:534 [3] NCCL INFO threadThresholds 8/8/64 | 256/8/64 | 8/8/64
# [1,11]<stdout>:algo-2:284:534 [3] NCCL INFO 4 coll channels, 4 p2p channels, 1 p2p channels per peer
# [1,11]<stdout>:algo-2:284:534 [3] NCCL INFO comm 0x7f58683988c0 rank 11 nranks 32 cudaDev 3 busId 201d0 - Init COMPLETE
# [1,0]<stdout>:algo-1:397:556 [0] NCCL INFO Launch mode Parallel
# [1,0]<stdout>:step: 0, step time: 2.1047, train_loss: 10.8109, top_1_accuracy: 0.0000, learning_rate: 0.0016
# [1,0]<stdout>:step: 50, step time: 1.7001, train_loss: 10.7307, top_1_accuracy: 0.0000, learning_rate: 0.0174
# [1,0]<stdout>:step: 100, step time: 0.7865, train_loss: 10.5836, top_1_accuracy: 0.0078, learning_rate: 0.0333
# [1,0]<stdout>:step: 150, step time: 0.7719, train_loss: 10.4880, top_1_accuracy: 0.0078, learning_rate: 0.0491
# [1,0]<stdout>:step: 200, step time: 0.7664, train_loss: 10.4363, top_1_accuracy: 0.0312, learning_rate: 0.0650
# [1,0]<stdout>:step: 250, step time: 0.8112, train_loss: 10.2054, top_1_accuracy: 0.0547, learning_rate: 0.0808
# [1,0]<stdout>:step: 300, step time: 0.7271, train_loss: 10.2221, top_1_accuracy: 0.0312, learning_rate: 0.0966
# [1,0]<stdout>:Starting validation Epoch 0/120
# [1,0]<stdout>:Validation Accuracy: 0.027445475260416668, Validation Loss: 6.283095836639404
# [1,0]<stdout>:Starting training Epoch 1/120
# [1,0]<stdout>:step: 0, step time: 0.6136, train_loss: 10.3025, top_1_accuracy: 0.0078, learning_rate: 0.1004
# [1,0]<stdout>:step: 50, step time: 0.2462, train_loss: 10.0476, top_1_accuracy: 0.0078, learning_rate: 0.1163
# [1,0]<stdout>:step: 100, step time: 0.2447, train_loss: 10.0626, top_1_accuracy: 0.0078, learning_rate: 0.1321
# [1,0]<stdout>:step: 150, step time: 0.2483, train_loss: 10.0762, top_1_accuracy: 0.0234, learning_rate: 0.1480
# [1,0]<stdout>:step: 200, step time: 0.2464, train_loss: 9.9113, top_1_accuracy: 0.0312, learning_rate: 0.1600
# [1,0]<stdout>:step: 250, step time: 0.2455, train_loss: 9.7322, top_1_accuracy: 0.0312, learning_rate: 0.1600
# [1,0]<stdout>:step: 300, step time: 0.2450, train_loss: 9.6587, top_1_accuracy: 0.0703, learning_rate: 0.1600
# [1,0]<stdout>:Starting validation Epoch 1/120
# [1,0]<stdout>:Validation Accuracy: 0.06528727213541667, Validation Loss: 5.7819743156433105
# [1,0]<stdout>:Starting training Epoch 2/120
# [1,0]<stdout>:step: 0, step time: 0.1029, train_loss: 9.7775, top_1_accuracy: 0.0391, learning_rate: 0.1600
# [1,0]<stdout>:step: 50, step time: 0.2467, train_loss: 9.5325, top_1_accuracy: 0.0703, learning_rate: 0.1600
# [1,0]<stdout>:step: 100, step time: 0.2448, train_loss: 9.3758, top_1_accuracy: 0.0938, learning_rate: 0.1600
# [1,0]<stdout>:step: 150, step time: 0.2456, train_loss: 9.4978, top_1_accuracy: 0.0938, learning_rate: 0.1600
# [1,0]<stdout>:step: 200, step time: 0.2437, train_loss: 9.4997, top_1_accuracy: 0.0625, learning_rate: 0.1600
# [1,0]<stdout>:step: 250, step time: 0.2472, train_loss: 9.3105, top_1_accuracy: 0.0703, learning_rate: 0.1600
# [1,0]<stdout>:step: 300, step time: 0.2471, train_loss: 9.2333, top_1_accuracy: 0.0703, learning_rate: 0.1599
# [1,0]<stdout>:Starting validation Epoch 2/120
# [1,0]<stdout>:Validation Accuracy: 0.09478759765625, Validation Loss: 5.426055431365967
# [1,0]<stdout>:Starting training Epoch 3/120
# [1,0]<stdout>:step: 0, step time: 0.1002, train_loss: 9.3537, top_1_accuracy: 0.0547, learning_rate: 0.1599
# [1,0]<stdout>:step: 50, step time: 0.2449, train_loss: 9.2384, top_1_accuracy: 0.1016, learning_rate: 0.1599
# [1,0]<stdout>:step: 100, step time: 0.2440, train_loss: 8.9825, top_1_accuracy: 0.0938, learning_rate: 0.1599
# [1,0]<stdout>:step: 150, step time: 0.2447, train_loss: 9.1332, top_1_accuracy: 0.0469, learning_rate: 0.1599
# [1,0]<stdout>:step: 200, step time: 0.2488, train_loss: 8.8494, top_1_accuracy: 0.1328, learning_rate: 0.1599
# [1,0]<stdout>:step: 250, step time: 0.2442, train_loss: 8.6271, top_1_accuracy: 0.1250, learning_rate: 0.1599
# [1,0]<stdout>:step: 300, step time: 0.2452, train_loss: 8.7668, top_1_accuracy: 0.0859, learning_rate: 0.1598
# [1,0]<stdout>:Starting validation Epoch 3/120
# [1,0]<stdout>:Validation Accuracy: 0.1312255859375, Validation Loss: 5.1578521728515625
# [1,0]<stdout>:Starting training Epoch 4/120
# [1,0]<stdout>:step: 0, step time: 0.0998, train_loss: 8.7323, top_1_accuracy: 0.1094, learning_rate: 0.1598
# [1,0]<stdout>:step: 50, step time: 0.2459, train_loss: 8.7400, top_1_accuracy: 0.1484, learning_rate: 0.1598
# [1,0]<stdout>:step: 100, step time: 0.2460, train_loss: 8.5220, top_1_accuracy: 0.0938, learning_rate: 0.1598
# [1,0]<stdout>:step: 150, step time: 0.2454, train_loss: 8.3048, top_1_accuracy: 0.1406, learning_rate: 0.1598
# [1,0]<stdout>:step: 200, step time: 0.2454, train_loss: 8.3003, top_1_accuracy: 0.1953, learning_rate: 0.1597
# [1,0]<stdout>:step: 250, step time: 0.2442, train_loss: 8.2858, top_1_accuracy: 0.2109, learning_rate: 0.1597
# [1,0]<stdout>:step: 300, step time: 0.2453, train_loss: 8.3975, top_1_accuracy: 0.1484, learning_rate: 0.1597
# [1,0]<stdout>:Starting validation Epoch 4/120
# [1,0]<stdout>:Validation Accuracy: 0.19264729817708334, Validation Loss: 4.709741115570068
# [1,0]<stdout>:Starting training Epoch 5/120
# [1,0]<stdout>:step: 0, step time: 0.1817, train_loss: 8.2683, top_1_accuracy: 0.1641, learning_rate: 0.1597
# [1,0]<stdout>:step: 50, step time: 0.2456, train_loss: 8.1055, top_1_accuracy: 0.1875, learning_rate: 0.1597
# [1,0]<stdout>:step: 100, step time: 0.2446, train_loss: 8.3830, top_1_accuracy: 0.1484, learning_rate: 0.1596
# [1,0]<stdout>:step: 150, step time: 0.2479, train_loss: 8.1083, top_1_accuracy: 0.1562, learning_rate: 0.1596
# [1,0]<stdout>:step: 200, step time: 0.2484, train_loss: 8.0802, top_1_accuracy: 0.1562, learning_rate: 0.1596
# [1,0]<stdout>:step: 250, step time: 0.2449, train_loss: 8.1559, top_1_accuracy: 0.1797, learning_rate: 0.1595
# [1,0]<stdout>:step: 300, step time: 0.2471, train_loss: 7.9989, top_1_accuracy: 0.1406, learning_rate: 0.1595
# [1,0]<stdout>:Starting validation Epoch 5/120
# [1,0]<stdout>:Validation Accuracy: 0.2293701171875, Validation Loss: 4.432047367095947
# [1,0]<stdout>:Starting training Epoch 6/120
# [1,0]<stdout>:step: 0, step time: 0.1007, train_loss: 7.9568, top_1_accuracy: 0.1953, learning_rate: 0.1595
# [1,0]<stdout>:step: 50, step time: 0.2470, train_loss: 7.6171, top_1_accuracy: 0.2344, learning_rate: 0.1594
# [1,0]<stdout>:step: 100, step time: 0.2460, train_loss: 7.6508, top_1_accuracy: 0.2422, learning_rate: 0.1594
# [1,0]<stdout>:step: 150, step time: 0.2473, train_loss: 7.6123, top_1_accuracy: 0.2578, learning_rate: 0.1593
# [1,0]<stdout>:step: 200, step time: 0.2463, train_loss: 7.7383, top_1_accuracy: 0.2422, learning_rate: 0.1593
# [1,0]<stdout>:step: 250, step time: 0.2471, train_loss: 7.7195, top_1_accuracy: 0.2656, learning_rate: 0.1593
# [1,0]<stdout>:step: 300, step time: 0.2463, train_loss: 7.5120, top_1_accuracy: 0.2344, learning_rate: 0.1592
# [1,0]<stdout>:Starting validation Epoch 6/120
# [1,0]<stdout>:Validation Accuracy: 0.25746663411458337, Validation Loss: 4.228569984436035
# [1,0]<stdout>:Starting training Epoch 7/120
# [1,0]<stdout>:step: 0, step time: 0.1011, train_loss: 7.6108, top_1_accuracy: 0.2422, learning_rate: 0.1592
# [1,0]<stdout>:step: 50, step time: 0.2449, train_loss: 7.3689, top_1_accuracy: 0.2891, learning_rate: 0.1592
# [1,0]<stdout>:step: 100, step time: 0.2455, train_loss: 7.4760, top_1_accuracy: 0.2969, learning_rate: 0.1591
# [1,0]<stdout>:step: 150, step time: 0.2473, train_loss: 7.5496, top_1_accuracy: 0.2266, learning_rate: 0.1591
# [1,0]<stdout>:step: 200, step time: 0.2470, train_loss: 7.4716, top_1_accuracy: 0.2500, learning_rate: 0.1590
# [1,0]<stdout>:step: 250, step time: 0.2461, train_loss: 7.5893, top_1_accuracy: 0.2578, learning_rate: 0.1589
# [1,0]<stdout>:step: 300, step time: 0.2468, train_loss: 7.3457, top_1_accuracy: 0.2344, learning_rate: 0.1589
# [1,0]<stdout>:Starting validation Epoch 7/120
# [1,0]<stdout>:Validation Accuracy: 0.322021484375, Validation Loss: 3.884046792984009
# [1,0]<stdout>:Starting training Epoch 8/120
# [1,0]<stdout>:step: 0, step time: 0.1004, train_loss: 7.2230, top_1_accuracy: 0.2969, learning_rate: 0.1589
# [1,0]<stdout>:step: 50, step time: 0.2495, train_loss: 7.1231, top_1_accuracy: 0.3828, learning_rate: 0.1588
# [1,0]<stdout>:step: 100, step time: 0.2476, train_loss: 7.0923, top_1_accuracy: 0.3125, learning_rate: 0.1588
# [1,0]<stdout>:step: 150, step time: 0.2455, train_loss: 7.3420, top_1_accuracy: 0.2578, learning_rate: 0.1587
# [1,0]<stdout>:step: 200, step time: 0.2462, train_loss: 7.0908, top_1_accuracy: 0.3359, learning_rate: 0.1586
# [1,0]<stdout>:step: 250, step time: 0.2455, train_loss: 6.9813, top_1_accuracy: 0.3125, learning_rate: 0.1586
# [1,0]<stdout>:step: 300, step time: 0.2460, train_loss: 7.0562, top_1_accuracy: 0.2266, learning_rate: 0.1585
# [1,0]<stdout>:Starting validation Epoch 8/120
# [1,0]<stdout>:Validation Accuracy: 0.3446044921875, Validation Loss: 3.750260591506958
# [1,0]<stdout>:Starting training Epoch 9/120
# [1,0]<stdout>:step: 0, step time: 0.1005, train_loss: 7.0338, top_1_accuracy: 0.3359, learning_rate: 0.1585
# [1,0]<stdout>:step: 50, step time: 0.2473, train_loss: 6.7503, top_1_accuracy: 0.3281, learning_rate: 0.1584
# [1,0]<stdout>:step: 100, step time: 0.2478, train_loss: 6.6116, top_1_accuracy: 0.3594, learning_rate: 0.1584
# [1,0]<stdout>:step: 150, step time: 0.2442, train_loss: 6.7154, top_1_accuracy: 0.3438, learning_rate: 0.1583
# [1,0]<stdout>:step: 200, step time: 0.2468, train_loss: 7.0956, top_1_accuracy: 0.3203, learning_rate: 0.1582
# [1,0]<stdout>:step: 250, step time: 0.2441, train_loss: 6.7942, top_1_accuracy: 0.3438, learning_rate: 0.1582
# [1,0]<stdout>:step: 300, step time: 0.2471, train_loss: 6.6374, top_1_accuracy: 0.3594, learning_rate: 0.1581
# [1,0]<stdout>:Starting validation Epoch 9/120
# [1,0]<stdout>:Validation Accuracy: 0.35994466145833337, Validation Loss: 3.697880268096924
# [1,0]<stdout>:Starting training Epoch 10/120
# [1,0]<stdout>:step: 0, step time: 0.1025, train_loss: 7.0652, top_1_accuracy: 0.3516, learning_rate: 0.1581
# [1,0]<stdout>:step: 50, step time: 0.2467, train_loss: 6.4289, top_1_accuracy: 0.3359, learning_rate: 0.1580
# [1,0]<stdout>:step: 100, step time: 0.2448, train_loss: 6.8083, top_1_accuracy: 0.3203, learning_rate: 0.1579
# [1,0]<stdout>:step: 150, step time: 0.2448, train_loss: 6.6792, top_1_accuracy: 0.3750, learning_rate: 0.1579
# [1,0]<stdout>:step: 200, step time: 0.2449, train_loss: 6.7121, top_1_accuracy: 0.3125, learning_rate: 0.1578
